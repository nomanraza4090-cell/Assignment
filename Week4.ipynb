# %% [markdown]
# ## 1 Pandas DataFrame Master

# %%
# Perform merging, grouping, concatenation and binning operations in Pandas.

import pandas as pd
import numpy as np

employees = pd.DataFrame({
    'Employee_ID': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    'Name': ['Alice Johnson', 'Bob Smith', 'Charlie Brown', 'David Wilson', 
             'Eve Davis', 'Frank Miller', 'Grace Lee', 'Henry Taylor', 
             'Ivy Chen', 'Jack Jones'],
    'Age': [28, 35, 42, 31, 26, 38, 29, 45, 33, 27],
    'Department_ID': ['D01', 'D02', 'D01', 'D03', 'D02', 'D01', 'D03', 'D02', 'D01', 'D03'],
     'Salary': [85000, 72000, 95000, 68000, 78000, 88000, 71000, 92000, 82000, 65000]

})

# 2. DEPARTMENTS DATAFRAME
departments = pd.DataFrame({
    'Department_ID': ['D01', 'D02', 'D03', 'D04', 'D05'],
    'Department_Name': ['Engineering', 'Marketing', 'Sales', 'Human Resources', 'Finance'],
    'Location': ['New York', 'San Francisco', 'Chicago', 'Boston', 'Seattle'],
    'Manager_ID': [101, 105, 108, None, None]  # None for departments without manager
})

# 3. SALARIES DATAFRAME
salaries = pd.DataFrame({
    'Employee_ID': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    'Bonus': [5000, 3000, 7000, 2000, 4000, 6000, 2500, 8000, 4500, 1500],
    
})

print(employees)
print(departments)
print(salaries)
# Out:
#    Employee_ID           Name  Age Department_ID  Salary
# 0          101  Alice Johnson   28           D01   85000
# 1          102      Bob Smith   35           D02   72000
# 2          103  Charlie Brown   42           D01   95000
# 3          104   David Wilson   31           D03   68000
# 4          105      Eve Davis   26           D02   78000
# 5          106   Frank Miller   38           D01   88000
# 6          107      Grace Lee   29           D03   71000
# 7          108   Henry Taylor   45           D02   92000
# 8          109       Ivy Chen   33           D01   82000
# 9          110     Jack Jones   27           D03   65000
#   Department_ID  Department_Name       Location  Manager_ID
# 0           D01      Engineering       New York       101.0
# 1           D02        Marketing  San Francisco       105.0
# 2           D03            Sales        Chicago       108.0
# 3           D04  Human Resources         Boston         NaN
# ...

# %%
pd.merge(employees, departments , how='inner')
# Out:
#    Employee_ID           Name  Age Department_ID  Salary Department_Name  \
# 0          101  Alice Johnson   28           D01   85000     Engineering
# 1          102      Bob Smith   35           D02   72000       Marketing
# 2          103  Charlie Brown   42           D01   95000     Engineering
# 3          104   David Wilson   31           D03   68000           Sales
# 4          105      Eve Davis   26           D02   78000       Marketing
# 5          106   Frank Miller   38           D01   88000     Engineering
# 6          107      Grace Lee   29           D03   71000           Sales
# 7          108   Henry Taylor   45           D02   92000       Marketing
# 8          109       Ivy Chen   33           D01   82000     Engineering
# 9          110     Jack Jones   27           D03   65000           Sales
#
#         Location  Manager_ID
# 0       New York       101.0
# 1  San Francisco       105.0
# 2       New York       101.0
# 3        Chicago       108.0
# ...

# %%
pd.merge(employees, departments, how='left')
# Out:
#    Employee_ID           Name  Age Department_ID  Salary Department_Name  \
# 0          101  Alice Johnson   28           D01   85000     Engineering
# 1          102      Bob Smith   35           D02   72000       Marketing
# 2          103  Charlie Brown   42           D01   95000     Engineering
# 3          104   David Wilson   31           D03   68000           Sales
# 4          105      Eve Davis   26           D02   78000       Marketing
# 5          106   Frank Miller   38           D01   88000     Engineering
# 6          107      Grace Lee   29           D03   71000           Sales
# 7          108   Henry Taylor   45           D02   92000       Marketing
# 8          109       Ivy Chen   33           D01   82000     Engineering
# 9          110     Jack Jones   27           D03   65000           Sales
#
#         Location  Manager_ID
# 0       New York       101.0
# 1  San Francisco       105.0
# 2       New York       101.0
# 3        Chicago       108.0
# ...

# %%
pd.merge(employees , departments , how='outer')
# Out:
#     Employee_ID           Name   Age Department_ID   Salary  Department_Name  \
# 0         101.0  Alice Johnson  28.0           D01  85000.0      Engineering
# 1         103.0  Charlie Brown  42.0           D01  95000.0      Engineering
# 2         106.0   Frank Miller  38.0           D01  88000.0      Engineering
# 3         109.0       Ivy Chen  33.0           D01  82000.0      Engineering
# 4         102.0      Bob Smith  35.0           D02  72000.0        Marketing
# 5         105.0      Eve Davis  26.0           D02  78000.0        Marketing
# 6         108.0   Henry Taylor  45.0           D02  92000.0        Marketing
# 7         104.0   David Wilson  31.0           D03  68000.0            Sales
# 8         107.0      Grace Lee  29.0           D03  71000.0            Sales
# 9         110.0     Jack Jones  27.0           D03  65000.0            Sales
# 10          NaN            NaN   NaN           D04      NaN  Human Resources
# ...

# %%
new_employees = pd.DataFrame({
    'Employee_ID': [111, 112, 113, 114, 115],
    'Name': ['Kevin Martinez', 'Linda Chen', 'Michael Scott', 
             'Patricia Williams', 'Robert Johnson'],
    'Age': [29, 34, 41, 37, 32],
    'Department_ID': ['D04', 'D02', 'D01', 'D03', 'D05']
})


updated_employees = pd.concat([employees, new_employees], ignore_index=True)
print(updated_employees)
# Out:
#     Employee_ID               Name  Age Department_ID   Salary
# 0           101      Alice Johnson   28           D01  85000.0
# 1           102          Bob Smith   35           D02  72000.0
# 2           103      Charlie Brown   42           D01  95000.0
# 3           104       David Wilson   31           D03  68000.0
# 4           105          Eve Davis   26           D02  78000.0
# 5           106       Frank Miller   38           D01  88000.0
# 6           107          Grace Lee   29           D03  71000.0
# 7           108       Henry Taylor   45           D02  92000.0
# 8           109           Ivy Chen   33           D01  82000.0
# 9           110         Jack Jones   27           D03  65000.0
# 10          111     Kevin Martinez   29           D04      NaN
# 11          112         Linda Chen   34           D02      NaN
# 12          113      Michael Scott   41           D01      NaN
# 13          114  Patricia Williams   37           D03      NaN
# ...

# %%
pd.merge(employees , salaries)
# Out:
#    Employee_ID           Name  Age Department_ID  Salary  Bonus
# 0          101  Alice Johnson   28           D01   85000   5000
# 1          102      Bob Smith   35           D02   72000   3000
# 2          103  Charlie Brown   42           D01   95000   7000
# 3          104   David Wilson   31           D03   68000   2000
# 4          105      Eve Davis   26           D02   78000   4000
# 5          106   Frank Miller   38           D01   88000   6000
# 6          107      Grace Lee   29           D03   71000   2500
# 7          108   Henry Taylor   45           D02   92000   8000
# 8          109       Ivy Chen   33           D01   82000   4500
# 9          110     Jack Jones   27           D03   65000   1500

# %%
avg_salary = employees.groupby('Department_ID')['Salary'].mean()
avg_salary
# Out:
# Department_ID
# D01    87500.000000
# D02    80666.666667
# D03    68000.000000
# Name: Salary, dtype: float64

# %% [markdown]
# ## 2 Data Visualization with Pandas and Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("Sales.csv")
df
# Out:
#      order_id        date region   product     category customer_type  \
# 0           1  2024-04-12   East    Laptop  Electronics     Returning
# 1           2  2024-12-14  South   Monitor  Accessories     Returning
# 2           3  2024-09-27  North     Phone  Accessories           New
# 3           4  2024-04-16   West     Mouse  Electronics     Returning
# 4           5  2024-03-12   West     Phone  Electronics     Returning
# ..        ...         ...    ...       ...          ...           ...
# 495       496  2024-11-20  South     Mouse  Accessories     Returning
# 496       497  2024-01-04  North     Phone  Accessories     Returning
# 497       498  2024-01-16  South  Keyboard  Electronics     Returning
# 498       499  2024-10-06  North     Phone  Accessories     Returning
# 499       500  2024-12-01  North   Monitor  Electronics           New
#
#      quantity  price  discount    sales
# 0           8    590      0.09  4295.20
# 1           2    262      0.18   429.68
# ...

# %% [markdown]
# ### Pandas Visualizations:

# %%
sns.lineplot(data=df, x="product", y="price")
# Out:
# <Axes: xlabel='product', ylabel='price'>

# %%
sns.barplot(data=df , x="product", y="sales")
# Out:
# <Axes: xlabel='product', ylabel='sales'>

# %%
df.groupby('region')['sales'].sum().plot(kind='pie', autopct='%1.1f%%', figsize=(8, 8), title='Total Sales by Region', colors=['gold', 'lightcoral', 'lightskyblue', 'lightgreen']); plt.ylabel(''); plt.show()

# %% [markdown]
# ### Seaborn Distribution Plots:

# %%
sns.histplot(data=df, x='product', kde=True, bins=30)
# Out:
# <Axes: xlabel='product', ylabel='Count'>

# %%
sns.jointplot(data=df, x='product', y='price')

# %% [markdown]
# ### Seaborn Categorical Plots:

# %%
sns.boxplot(data=df, x='region', y='product')
# Out:
# <Axes: xlabel='region', ylabel='product'>

# %%
sns.barplot(data=df, x='product', y='price', estimator=np.mean)
# Out:
# <Axes: xlabel='product', ylabel='price'>
